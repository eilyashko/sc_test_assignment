# %%
from pathlib import Path
import sys
from dotenv import load_dotenv


def find_repo_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "SQL").is_dir():
            return p
    return start


repo_root = find_repo_root(Path.cwd())

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

sql_env = repo_root / "SQL" / ".env"
root_env = repo_root / ".env"
dotenv_path = sql_env if sql_env.exists() else (root_env if root_env.exists() else None)
if dotenv_path:
    load_dotenv(dotenv_path=dotenv_path)
else:
    load_dotenv()

from SQL.snowflake_client import SnowflakeClient

# Create a reusable client for the session
if 'client' in globals():
    try:
        client.close()
    except Exception:
        pass
client = SnowflakeClient.from_env()

# %%
# Sample: select from calls with triple-quoted SQL
query = """
SELECT * FROM cases
LIMIT 100
"""

df = client.query_to_df(query)
df.head(100)
# Out:
#                CASE_ID        CREATED_DATE         CLOSED_DATE  CASE_ORIGIN  \
# 0   500dV00000Dt3ApQAJ 2025-08-04 04:33:14                 NaT   Backoffice
# 1   500dV00000DtsgGQAR 2025-08-04 08:11:24 2025-08-04 12:32:53        Phone
# 2   500dV00000DtsgIQAR 2025-08-04 08:24:10 2025-08-04 14:17:02  Form_Mobile
# 3   500dV00000DttXXQAZ 2025-08-04 00:48:01 2025-08-04 14:17:02  Form_Mobile
# 4   500dV00000Dtv80QAB 2025-08-04 00:51:30 2025-08-04 14:00:30  Form_Mobile
# ..                 ...                 ...                 ...          ...
# 95  500dV00000DuQVAQA3 2025-08-04 09:13:37                 NaT  Form_Mobile
# 96  500dV00000DuQrZQAV 2025-08-04 07:14:34 2025-08-04 14:18:58  Form_Mobile
# 97  500dV00000DuQtPQAV 2025-08-04 08:59:47 2025-08-05 09:08:29  Form_Mobile
# 98  500dV00000DuR2xQAF 2025-08-04 09:39:52 2025-08-11 11:50:30  Form_Mobile
# 99  500dV00000DuR9TQAV 2025-08-04 08:10:00                 NaT        Email
#
#     NUMBER_OF_EMAILS_RECEIVED  NUMBER_OF_EMAILS_SENT      CONTACT_REASON  \
# 0                         NaN                    2.0  Systemic in Nature
# 1                         NaN                    2.0        System Issue
# 2                         1.0                    1.0    Product Question
# 3                         1.0                    1.0    Product Question
# 4                         1.0                    1.0    Product Question
# ..                        ...                    ...                 ...
# 95                        1.0                    NaN                Null
# 96                        1.0                    1.0    Product Question
# 97                        1.0                    1.0    Product Question
# 98                        1.0                    1.0        New Scalable
# 99                        1.0                    1.0                Null
#
#                 BUCKET                            TOPIC             SUB_TOPIC
# 0      Account Opening           Account Opening - MISC                  None
# 1   Account Management         Account Management - 2FA                  None
# 2    Corporate Actions  Corporate Actions - Stock Split  Securities Statement
# 3    Corporate Actions  Corporate Actions - Stock Split                  None
# 4    Corporate Actions  Corporate Actions - Stock Split                  None
# ..                 ...                              ...                   ...
# 95   Corporate Actions  Corporate Actions - Stock Split                  None
# 96   Corporate Actions  Corporate Actions - Stock Split                  None
# 97            Payments           Payments - Withdrawals                  None
# 98      Broker Trading   Broker Trading - Savings Plans                  None
# 99      Broker Trading            Broker Trading - MISC                  None
#
# [100 rows x 10 columns]

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH anchor AS (
  SELECT TO_TIMESTAMP_NTZ('2025-08-13 10:06:21') AS window_end
),
enriched AS (
  SELECT
    c.*,
    -- Open as of anchor (handles future/NULL closures defensively)
    IFF(c.CLOSED_DATE IS NULL OR c.CLOSED_DATE > (SELECT window_end FROM anchor), 1, 0) AS is_open_asof,
    -- Age measured to CLOSED_DATE (if before anchor) or to anchor (if open/after)
    DATEDIFF(
      'hour',
      c.CREATED_DATE,
      LEAST(COALESCE(c.CLOSED_DATE, (SELECT window_end FROM anchor)), (SELECT window_end FROM anchor))
    ) AS age_hours_asof
  FROM SCALABLECAPITAL.PUBLIC.CASES c
)
SELECT
  BUCKET,
  TOPIC,
  COUNT_IF(is_open_asof = 1)                               AS open_now,
  COUNT_IF(is_open_asof = 1 AND age_hours_asof >= 24)      AS open_gt_1d,
  COUNT_IF(is_open_asof = 1 AND age_hours_asof >= 72)      AS open_gt_3d,
  COUNT_IF(is_open_asof = 1 AND age_hours_asof >= 168)     AS open_gt_7d
FROM enriched
GROUP BY 1,2
ORDER BY open_now DESC, BUCKET, TOPIC;;


"""

df = client.query_to_df(query)
df.head(100)
# Out:
#                          BUCKET  \
# 0                Broker Trading
# 1   Broker Portfolio Management
# 2            Account Management
# 3                Broker Trading
# 4               Account Opening
# 5                         Taxes
# 6                          Null
# 7   Broker Portfolio Management
# 8                Broker Trading
# 9             Corporate Actions
# 10           Account Management
# 11                        Taxes
# 12                        Taxes
# 13           Account Management
# 14                        Taxes
# 15              Account Opening
# 16            Corporate Actions
# 17            Corporate Actions
# 18              Account Opening
# 19                     Payments
# 20  Broker Portfolio Management
# 21           Account Management
# 22           Account Management
# 23           Account Management
# 24                     Payments
# 25                     Payments
# 26  Broker Portfolio Management
# 27                     Payments
# 28                        Taxes
# 29                        Taxes
# 30                     Payments
# 31              Account Opening
# 32                     Goodwill
# 33                     Goodwill
# 34                        Taxes
# 35                        Taxes
# 36               Broker Trading
# 37                     Goodwill
# 38           Account Management
# 39           Account Management
# 40               Broker Trading
# 41                     Goodwill
# 42               Broker Trading
# 43               Broker Trading
# 44            Corporate Actions
# 45               Broker Trading
# 46            Corporate Actions
# 47                     Goodwill
# 48                     Payments
# 49               Broker Trading
# 50            Corporate Actions
# 51                        Other
#
#                                              TOPIC  OPEN_NOW  OPEN_GT_1D  \
# 0                            Broker Trading - MISC       253         253
# 1        Broker Portfolio Management - Transfer IN       193         193
# 2                 Account Management - Data Change       178         178
# 3                   Broker Trading - Savings Plans       142         142
# 4                           Account Opening - MISC       138         138
# 5                                     Taxes - MISC       133         133
# 6                                             Null       115         115
# 7               Broker Portfolio Management - MISC       113         113
# 8                    Broker Trading - Trade Issues        91          91
# 9                  Corporate Actions - Stock Split        84          84
# 10                       Account Management - MISC        83          83
# 11                 Taxes - Tax Calculation Details        62          62
# 12                  Taxes - Yearly Tax Certificate        58          58
# 13           Account Management - Client Documents        55          55
# 14                           Taxes - Tax Allowance        52          52
# 15                           Account Opening - KYC        50          50
# 16                        Corporate Actions - MISC        50          50
# 17           Corporate Actions - Dividend Payments        47          47
# 18               Account Opening - Opening Process        44          44
# 19                             Payments - Deposits        40          40
# 20      Broker Portfolio Management - Transfer OUT        36          36
# 21               Account Management - Cancellation        35          35
# 22                  Account Management - IT Issues        31          31
# 23                        Account Management - 2FA        28          28
# 24                          Payments - Withdrawals        19          19
# 25                                 Payments - MISC        18          18
# 26  Broker Portfolio Management - Broker Functions        17          17
# 27                      Payments - Account Balance        17          17
# 28          Taxes - German Tax ID and Church Taxes        16          16
# 29                                  Taxes - W8-Ben        14          14
# 30                               Payments - Credit        10          10
# 31          Account Opening - Account Reactivation         9           9
# 32                                 Goodwill - Fees         9           9
# 33                             Goodwill - Referral         9           9
# 34                          Taxes - Non Assessment         9           9
# 35            Taxes - Loss Pot Certificate Request         8           8
# 36                    Broker Trading - Derivatives         7           7
# 37                              Goodwill - Rewards         6           6
# 38              Account Management - Data Deletion         5           5
# 39           Account Management - Non-EU Residents         5           5
# 40                         Broker Trading - Crypto         5           5
# 41                              Goodwill - Refunds         5           5
# 42                       Broker Trading - Downtime         3           3
# 43                    Broker Trading - EIX Support         3           3
# 44            Corporate Actions - Capital Increase         3           3
# 45             Broker Trading - Order Instructions         1           1
# 46                Corporate Actions - Instructions         1           1
# 47                                 Goodwill - MISC         1           1
# 48                             Payments - Interest         1           1
# 49              Broker Trading - Scalable Products         0           0
# 50                    Corporate Actions - Spin-off         0           0
# 51                               Other - Marketing         0           0
#
#     OPEN_GT_3D  OPEN_GT_7D
# 0          243         114
# 1          188          95
# 2          161          67
# 3          140          73
# 4          124          52
# 5          130          54
# 6          112          52
# 7          109          40
# 8           90          44
# 9           84          59
# 10          73          26
# 11          58          25
# 12          53          23
# 13          51          20
# 14          49          20
# 15          47          19
# 16          48          21
# 17          43          20
# 18          44          18
# 19          38          10
# 20          34          15
# 21          32           7
# 22          31          13
# 23          28          12
# 24          18           3
# 25          16           3
# 26          16           8
# 27          15           5
# 28          16           7
# 29          13           7
# 30           9           0
# 31           9           1
# 32           9           3
# 33           8           3
# 34           8           6
# 35           8           6
# 36           7           5
# 37           6           2
# 38           5           0
# 39           5           3
# 40           4           3
# 41           5           1
# 42           3           1
# 43           3           0
# 44           3           3
# 45           1           1
# 46           1           1
# 47           1           0
# 48           1           0
# 49           0           0
# 50           0           0
# 51           0           0

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH anchor AS (
  SELECT TO_TIMESTAMP_NTZ('2025-08-13 10:06:21') AS window_end
),
base AS (
  SELECT
    CASE_ID,
    CREATED_DATE,
    CLOSED_DATE,
    CASE_ORIGIN,
    NUMBER_OF_EMAILS_RECEIVED,
    NUMBER_OF_EMAILS_SENT,
    CONTACT_REASON,
    BUCKET,
    TOPIC,
    SUB_TOPIC
  FROM SCALABLECAPITAL.PUBLIC.CASES
),
enriched AS (
  SELECT
    b.*,
    IFF(b.CLOSED_DATE IS NULL OR b.CLOSED_DATE > (SELECT window_end FROM anchor), 1, 0) AS is_open_asof,
    DATEDIFF(
      'hour',
      b.CREATED_DATE,
      LEAST(COALESCE(b.CLOSED_DATE, (SELECT window_end FROM anchor)), (SELECT window_end FROM anchor))
    ) AS age_hours_asof,
    DATEDIFF('hour', b.CREATED_DATE, (SELECT window_end FROM anchor)) AS since_creation_to_anchor_hours,
    IFF(DATEDIFF('hour', b.CREATED_DATE, (SELECT window_end FROM anchor)) >=  24, 1, 0) AS elig_1d,
    IFF(DATEDIFF('hour', b.CREATED_DATE, (SELECT window_end FROM anchor)) >=  72, 1, 0) AS elig_3d,
    IFF(DATEDIFF('hour', b.CREATED_DATE, (SELECT window_end FROM anchor)) >= 168, 1, 0) AS elig_7d
  FROM base b
)
SELECT
  BUCKET,
  CAST(COUNT(*) AS NUMBER(38)) AS ORIGINATED_CASES,
  CAST(COUNT_IF(is_open_asof = 1) AS NUMBER(38)) AS OPEN_NOW,
  CAST(ROUND(COUNT_IF(is_open_asof = 1) / NULLIF(COUNT(*), 0), 2) AS NUMBER(38,2)) AS OPEN_NOW_RATE,
  CAST(ROUND(COUNT_IF(is_open_asof = 1 AND age_hours_asof >= 24)  / NULLIF(SUM(elig_1d), 0), 2) AS NUMBER(38,2)) AS OPEN_1D_RATE,
  CAST(ROUND(COUNT_IF(is_open_asof = 1 AND age_hours_asof >= 72)  / NULLIF(SUM(elig_3d), 0), 2) AS NUMBER(38,2)) AS OPEN_3D_RATE,
  CAST(ROUND(COUNT_IF(is_open_asof = 1 AND age_hours_asof >= 168) / NULLIF(SUM(elig_7d), 0), 2) AS NUMBER(38,2)) AS OPEN_7D_RATE
FROM enriched
GROUP BY 1
ORDER BY OPEN_NOW_RATE DESC, BUCKET;


"""

df = client.query_to_df(query)
df.head(100)
# Out:
#                         BUCKET ORIGINATED_CASES  OPEN_NOW OPEN_NOW_RATE  \
# 0                         Null              116       115          0.99
# 1                        Taxes              463       352          0.76
# 2               Broker Trading              929       505          0.54
# 3  Broker Portfolio Management              773       359          0.46
# 4            Corporate Actions              545       185          0.34
# 5              Account Opening              758       241          0.32
# 6                     Goodwill              112        30          0.27
# 7           Account Management             1759       420          0.24
# 8                     Payments              717       105          0.15
# 9                        Other               20         0          0.00
#
#   OPEN_1D_RATE OPEN_3D_RATE OPEN_7D_RATE
# 0         0.99         0.99         1.00
# 1         0.76         0.75         0.75
# 2         0.54         0.54         0.60
# 3         0.46         0.46         0.46
# 4         0.34         0.34         0.27
# 5         0.32         0.31         0.33
# 6         0.27         0.26         0.16
# 7         0.24         0.23         0.20
# 8         0.15         0.14         0.06
# 9         0.00         0.00         0.00

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH anchor AS (
  SELECT TO_TIMESTAMP_NTZ('2025-08-13 10:06:21') AS window_end
),
base AS (
  SELECT
    CASE_ID, CREATED_DATE, CLOSED_DATE, CASE_ORIGIN,
    NUMBER_OF_EMAILS_RECEIVED, NUMBER_OF_EMAILS_SENT,
    CONTACT_REASON, BUCKET, TOPIC, SUB_TOPIC
  FROM SCALABLECAPITAL.PUBLIC.CASES
  WHERE BUCKET IN ('Taxes','Broker Trading','Broker Portfolio Management')
),
enriched AS (
  SELECT
    b.*,
    IFF(b.CLOSED_DATE IS NULL OR b.CLOSED_DATE > (SELECT window_end FROM anchor), 1, 0) AS is_open_asof,
    DATEDIFF('hour', b.CREATED_DATE,
      LEAST(COALESCE(b.CLOSED_DATE, (SELECT window_end FROM anchor)), (SELECT window_end FROM anchor))
    ) AS age_hours_asof,
    IFF(DATEDIFF('hour', b.CREATED_DATE, (SELECT window_end FROM anchor)) >=  72, 1, 0) AS elig_3d,
    IFF(DATEDIFF('hour', b.CREATED_DATE, (SELECT window_end FROM anchor)) >= 168, 1, 0) AS elig_7d
  FROM base b
)
SELECT
  BUCKET,
  TOPIC,
  CAST(COUNT(*) AS NUMBER(38)) AS originated_cases,
  CAST(COUNT_IF(is_open_asof = 1) AS NUMBER(38)) AS open_now,
  CAST(ROUND(COUNT_IF(is_open_asof = 1) / NULLIF(COUNT(*), 0), 2) AS NUMBER(38,2))                    AS open_now_rate,

  CAST(ROUND(COUNT_IF(is_open_asof = 1 AND age_hours_asof >= 168) / NULLIF(SUM(elig_7d), 0), 2)
       AS NUMBER(38,2)) AS open_7d_rate
FROM enriched
GROUP BY 1,2
ORDER BY bucket, open_now desc, open_7d_rate desc;


"""

df = client.query_to_df(query)
df.head(100)
# Out:
#                          BUCKET  \
# 0   Broker Portfolio Management
# 1   Broker Portfolio Management
# 2   Broker Portfolio Management
# 3   Broker Portfolio Management
# 4                Broker Trading
# 5                Broker Trading
# 6                Broker Trading
# 7                Broker Trading
# 8                Broker Trading
# 9                Broker Trading
# 10               Broker Trading
# 11               Broker Trading
# 12               Broker Trading
# 13                        Taxes
# 14                        Taxes
# 15                        Taxes
# 16                        Taxes
# 17                        Taxes
# 18                        Taxes
# 19                        Taxes
# 20                        Taxes
#
#                                              TOPIC ORIGINATED_CASES  OPEN_NOW  \
# 0        Broker Portfolio Management - Transfer IN              291       193
# 1               Broker Portfolio Management - MISC              135       113
# 2       Broker Portfolio Management - Transfer OUT              318        36
# 3   Broker Portfolio Management - Broker Functions               29        17
# 4                            Broker Trading - MISC              298       253
# 5                   Broker Trading - Savings Plans              346       142
# 6                    Broker Trading - Trade Issues              174        91
# 7                     Broker Trading - Derivatives               19         7
# 8                          Broker Trading - Crypto               19         5
# 9                     Broker Trading - EIX Support                3         3
# 10                       Broker Trading - Downtime               29         3
# 11             Broker Trading - Order Instructions               17         1
# 12              Broker Trading - Scalable Products               24         0
# 13                                    Taxes - MISC              174       133
# 14                 Taxes - Tax Calculation Details               84        62
# 15                  Taxes - Yearly Tax Certificate               69        58
# 16                           Taxes - Tax Allowance               79        52
# 17          Taxes - German Tax ID and Church Taxes               19        16
# 18                                  Taxes - W8-Ben               15        14
# 19                          Taxes - Non Assessment               10         9
# 20            Taxes - Loss Pot Certificate Request               13         8
#
#    OPEN_NOW_RATE OPEN_7D_RATE
# 0           0.66         0.68
# 1           0.84         0.78
# 2           0.11         0.10
# 3           0.59         0.62
# 4           0.85         0.84
# 5           0.41         0.43
# 6           0.52         0.72
# 7           0.37         0.71
# 8           0.26         0.50
# 9           1.00         None
# 10          0.10         0.50
# 11          0.06         0.20
# 12          0.00         0.00
# 13          0.76         0.74
# 14          0.74         0.64
# 15          0.84         0.74
# 16          0.66         0.74
# 17          0.84         0.88
# 18          0.93         1.00
# 19          0.90         1.00
# 20          0.62         0.86

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH anchor AS (
  SELECT TO_TIMESTAMP_NTZ('2025-08-13 10:06:21') AS window_end
),
base AS (
  SELECT
    CASE_ID,
    CREATED_DATE,
    CLOSED_DATE,
    CASE_ORIGIN,
    NUMBER_OF_EMAILS_RECEIVED,
    NUMBER_OF_EMAILS_SENT,
    CONTACT_REASON,
    BUCKET,
    TOPIC,
    SUB_TOPIC
  FROM SCALABLECAPITAL.PUBLIC.CASES
  WHERE BUCKET IN ('Taxes','Broker Trading','Broker Portfolio Management')
),
enriched AS (
  SELECT
    b.*,
    IFF(b.CLOSED_DATE IS NULL OR b.CLOSED_DATE > (SELECT window_end FROM anchor), 1, 0) AS is_open_asof,
    DATEDIFF(
      'hour',
      b.CREATED_DATE,
      LEAST(COALESCE(b.CLOSED_DATE, (SELECT window_end FROM anchor)), (SELECT window_end FROM anchor))
    ) AS age_hours_asof,
    IFF(DATEDIFF('hour', b.CREATED_DATE, (SELECT window_end FROM anchor)) >=  72, 1, 0) AS elig_3d,
    IFF(DATEDIFF('hour', b.CREATED_DATE, (SELECT window_end FROM anchor)) >= 168, 1, 0) AS elig_7d
  FROM base b
)
SELECT
  BUCKET,
  TOPIC,
  CAST(COUNT(*) AS NUMBER(38)) AS ORIGINATED_CASES,
  CAST(COUNT_IF(is_open_asof = 1) AS NUMBER(38)) AS OPEN_NOW,
  CAST(ROUND(COUNT_IF(is_open_asof = 1) / NULLIF(COUNT(*), 0), 2) AS NUMBER(38,2)) AS OPEN_NOW_RATE,
  CAST(ROUND(COUNT_IF(is_open_asof = 1 AND age_hours_asof >= 168) / NULLIF(SUM(elig_7d), 0), 2) AS NUMBER(38,2)) AS OPEN_7D_RATE,
  CAST(
    ROUND(
      COUNT_IF(CONTACT_REASON = 'Null') / NULLIF(COUNT(*), 0),
      2
    ) AS NUMBER(38,2)
  ) AS PCT_CONTACT_REASON_NULL
FROM enriched
GROUP BY 1,2
ORDER BY BUCKET, PCT_CONTACT_REASON_NULL desc;

"""

df = client.query_to_df(query)
pd.set_option('display.max_rows', None)  
df
# Out:
#                          BUCKET  \
# 0   Broker Portfolio Management
# 1   Broker Portfolio Management
# 2   Broker Portfolio Management
# 3   Broker Portfolio Management
# 4                Broker Trading
# 5                Broker Trading
# 6                Broker Trading
# 7                Broker Trading
# 8                Broker Trading
# 9                Broker Trading
# 10               Broker Trading
# 11               Broker Trading
# 12               Broker Trading
# 13                        Taxes
# 14                        Taxes
# 15                        Taxes
# 16                        Taxes
# 17                        Taxes
# 18                        Taxes
# 19                        Taxes
# 20                        Taxes
#
#                                              TOPIC ORIGINATED_CASES  OPEN_NOW  \
# 0               Broker Portfolio Management - MISC              135       113
# 1        Broker Portfolio Management - Transfer IN              291       193
# 2   Broker Portfolio Management - Broker Functions               29        17
# 3       Broker Portfolio Management - Transfer OUT              318        36
# 4                            Broker Trading - MISC              298       253
# 5                     Broker Trading - EIX Support                3         3
# 6                    Broker Trading - Trade Issues              174        91
# 7                   Broker Trading - Savings Plans              346       142
# 8               Broker Trading - Scalable Products               24         0
# 9                     Broker Trading - Derivatives               19         7
# 10                         Broker Trading - Crypto               19         5
# 11                       Broker Trading - Downtime               29         3
# 12             Broker Trading - Order Instructions               17         1
# 13          Taxes - German Tax ID and Church Taxes               19        16
# 14                  Taxes - Yearly Tax Certificate               69        58
# 15                           Taxes - Tax Allowance               79        52
# 16                                  Taxes - W8-Ben               15        14
# 17                          Taxes - Non Assessment               10         9
# 18                                    Taxes - MISC              174       133
# 19                 Taxes - Tax Calculation Details               84        62
# 20            Taxes - Loss Pot Certificate Request               13         8
#
#    OPEN_NOW_RATE OPEN_7D_RATE PCT_CONTACT_REASON_NULL
# 0           0.84         0.78                    0.73
# 1           0.66         0.68                    0.53
# 2           0.59         0.62                    0.45
# 3           0.11         0.10                    0.16
# 4           0.85         0.84                    0.81
# 5           1.00         None                    0.67
# 6           0.52         0.72                    0.52
# 7           0.41         0.43                    0.28
# 8           0.00         0.00                    0.21
# 9           0.37         0.71                    0.21
# 10          0.26         0.50                    0.11
# 11          0.10         0.50                    0.07
# 12          0.06         0.20                    0.00
# 13          0.84         0.88                    0.84
# 14          0.84         0.74                    0.83
# 15          0.66         0.74                    0.77
# 16          0.93         1.00                    0.73
# 17          0.90         1.00                    0.70
# 18          0.76         0.74                    0.69
# 19          0.74         0.64                    0.63
# 20          0.62         0.86                    0.54

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH anchor AS (
  -- We still define the snapshot end because we will calculate observed_age_hours
  -- but for this speed metric we only keep actually closed cases
  SELECT TO_TIMESTAMP_NTZ('2025-08-13 10:06:21') AS window_end
),
base AS (
  SELECT
    CASE_ID,
    CREATED_DATE,
    CLOSED_DATE,
    CASE_ORIGIN,
    NUMBER_OF_EMAILS_RECEIVED,
    NUMBER_OF_EMAILS_SENT,
    CONTACT_REASON,
    BUCKET,
    TOPIC,
    SUB_TOPIC
  FROM SCALABLECAPITAL.PUBLIC.CASES
),
enriched AS (
  SELECT
    b.*,
    -- how long this case took from create to close, in hours
    DATEDIFF(
      'hour',
      b.CREATED_DATE,
      b.CLOSED_DATE
    ) AS ttc_hours,  -- time to close

    -- whether it closed the same calendar day it was opened
    IFF(
      DATE_TRUNC('day', b.CREATED_DATE) = DATE_TRUNC('day', b.CLOSED_DATE),
      1, 0
    ) AS same_day_flag
  FROM base b
  WHERE b.CLOSED_DATE IS NOT NULL
)
SELECT
  BUCKET,
  TOPIC,
  CAST(COUNT(*) AS NUMBER(38))                                        AS closed_cases,
  CAST(ROUND(MEDIAN(ttc_hours), 2) AS NUMBER(38,2))                    AS median_ttc_hours,
  CAST(ROUND(APPROX_PERCENTILE(ttc_hours, 0.90), 2) AS NUMBER(38,2))   AS p90_ttc_hours,
  CAST(ROUND(AVG(same_day_flag), 2) AS NUMBER(38,2))                   AS same_day_close_rate
FROM enriched
GROUP BY 1,2
HAVING closed_cases >= 10
ORDER BY bucket, topic, median_ttc_hours DESC;

"""

df = client.query_to_df(query)
pd.set_option('display.max_rows', None)  
df
# Out:
#                          BUCKET  \
# 0            Account Management
# 1            Account Management
# 2            Account Management
# 3            Account Management
# 4            Account Management
# 5            Account Management
# 6               Account Opening
# 7               Account Opening
# 8               Account Opening
# 9               Account Opening
# 10  Broker Portfolio Management
# 11  Broker Portfolio Management
# 12  Broker Portfolio Management
# 13  Broker Portfolio Management
# 14               Broker Trading
# 15               Broker Trading
# 16               Broker Trading
# 17               Broker Trading
# 18               Broker Trading
# 19               Broker Trading
# 20               Broker Trading
# 21               Broker Trading
# 22            Corporate Actions
# 23            Corporate Actions
# 24            Corporate Actions
# 25            Corporate Actions
# 26                     Goodwill
# 27                     Goodwill
# 28                        Other
# 29                     Payments
# 30                     Payments
# 31                     Payments
# 32                     Payments
# 33                     Payments
# 34                     Payments
# 35                        Taxes
# 36                        Taxes
# 37                        Taxes
# 38                        Taxes
#
#                                              TOPIC CLOSED_CASES  \
# 0                         Account Management - 2FA          154
# 1                Account Management - Cancellation          183
# 2            Account Management - Client Documents          285
# 3                 Account Management - Data Change          154
# 4                   Account Management - IT Issues          136
# 5                        Account Management - MISC          415
# 6           Account Opening - Account Reactivation          167
# 7                            Account Opening - KYC          116
# 8                           Account Opening - MISC           58
# 9                Account Opening - Opening Process          176
# 10  Broker Portfolio Management - Broker Functions           12
# 11              Broker Portfolio Management - MISC           22
# 12       Broker Portfolio Management - Transfer IN           98
# 13      Broker Portfolio Management - Transfer OUT          282
# 14                         Broker Trading - Crypto           14
# 15                    Broker Trading - Derivatives           12
# 16                       Broker Trading - Downtime           26
# 17                           Broker Trading - MISC           45
# 18             Broker Trading - Order Instructions           16
# 19                  Broker Trading - Savings Plans          204
# 20              Broker Trading - Scalable Products           24
# 21                   Broker Trading - Trade Issues           83
# 22           Corporate Actions - Dividend Payments           17
# 23                Corporate Actions - Instructions           44
# 24                        Corporate Actions - MISC           31
# 25                 Corporate Actions - Stock Split          266
# 26                                 Goodwill - Fees           25
# 27                             Goodwill - Referral           43
# 28                               Other - Marketing           20
# 29                      Payments - Account Balance           99
# 30                               Payments - Credit           28
# 31                             Payments - Deposits          209
# 32                             Payments - Interest           39
# 33                                 Payments - MISC           57
# 34                          Payments - Withdrawals          180
# 35                                    Taxes - MISC           41
# 36                           Taxes - Tax Allowance           27
# 37                 Taxes - Tax Calculation Details           22
# 38                  Taxes - Yearly Tax Certificate           11
#
#    MEDIAN_TTC_HOURS P90_TTC_HOURS SAME_DAY_CLOSE_RATE
# 0             23.00         79.40                0.38
# 1             24.00         86.00                0.19
# 2             23.00         73.60                0.27
# 3             25.00        167.00                0.11
# 4             23.00         83.00                0.22
# 5             23.00         74.00                0.41
# 6              0.00         71.40                0.66
# 7             65.50        140.50                0.11
# 8             51.00         94.00                0.29
# 9              1.00         72.50                0.60
# 10             0.00          1.90                0.92
# 11             3.50         66.30                0.59
# 12             0.50         67.60                0.70
# 13            22.00        105.60                0.41
# 14             0.50         37.10                0.64
# 15             1.00         16.00                0.83
# 16             2.00        120.00                0.65
# 17             0.00         26.20                0.76
# 18             1.00         34.50                0.75
# 19            13.00        144.00                0.50
# 20             1.00         34.70                0.71
# 21             2.00         32.60                0.81
# 22            25.00         85.00                0.47
# 23             1.00         45.90                0.64
# 24             0.00         49.00                0.77
# 25             5.00         19.50                0.80
# 26            33.00        103.40                0.36
# 27            24.00         84.00                0.16
# 28            22.00         30.70                0.35
# 29            23.00         74.20                0.33
# 30            55.00        110.60                0.29
# 31             9.00         72.20                0.52
# 32            24.00        127.00                0.36
# 33             9.00         66.00                0.54
# 34            24.00         86.30                0.26
# 35             1.00         26.00                0.76
# 36             0.00          4.60                0.89
# 37             9.00         52.60                0.50
# 38             0.00         16.00                0.73

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH anchor AS (
  SELECT TO_TIMESTAMP_NTZ('2025-08-13 10:06:21') AS window_end
),
base AS (
  SELECT
    CASE_ID, CREATED_DATE, CLOSED_DATE, CASE_ORIGIN,
    NUMBER_OF_EMAILS_RECEIVED, NUMBER_OF_EMAILS_SENT,
    CONTACT_REASON, BUCKET, TOPIC, SUB_TOPIC
  FROM SCALABLECAPITAL.PUBLIC.CASES
),
enriched AS (
  SELECT
    b.*,
    IFF(b.CLOSED_DATE IS NULL OR b.CLOSED_DATE > (SELECT window_end FROM anchor), 1, 0) AS is_open_asof,
    DATEDIFF('hour', b.CREATED_DATE,
      LEAST(COALESCE(b.CLOSED_DATE,(SELECT window_end FROM anchor)),(SELECT window_end FROM anchor))
    ) AS age_hours_asof,
    IFF(DATEDIFF('hour', b.CREATED_DATE, (SELECT window_end FROM anchor)) >= 168, 1, 0) AS elig_7d,
    COALESCE(NUMBER_OF_EMAILS_RECEIVED,0) + COALESCE(NUMBER_OF_EMAILS_SENT,0) AS emails_total,
    IFF(DATE_TRUNC('day', b.CREATED_DATE) = DATE_TRUNC('day', b.CLOSED_DATE), 1, 0) AS same_day_flag
  FROM base b
)
SELECT
  CASE_ORIGIN,
  CAST(COUNT(*) AS NUMBER(38))                                                        AS TOTAL_CASES,
  CAST(ROUND(COUNT(*) / NULLIF(SUM(COUNT(*)) OVER (), 0), 2) AS NUMBER(38,2))        AS SHARE_OF_TOTAL,
  CAST(COUNT_IF(is_open_asof = 1) AS NUMBER(38))                                      AS OPEN_NOW,
  CAST(ROUND(COUNT_IF(is_open_asof = 1) / NULLIF(COUNT(*), 0), 2) AS NUMBER(38,2))   AS OPEN_NOW_RATE,
  CAST(ROUND(COUNT_IF(is_open_asof = 1 AND age_hours_asof >= 168) /
             NULLIF(SUM(elig_7d), 0), 2) AS NUMBER(38,2))                             AS OPEN_7D_RATE,
  CAST(COUNT_IF(is_open_asof = 0) AS NUMBER(38))                                      AS CLOSED_CASES,
  CAST(ROUND(MEDIAN(IFF(is_open_asof=0, age_hours_asof, NULL)), 2) AS NUMBER(38,2))  AS MEDIAN_TTC_HOURS,
  CAST(ROUND(APPROX_PERCENTILE(IFF(is_open_asof=0, age_hours_asof, NULL), 0.90), 2)
       AS NUMBER(38,2))                                                               AS P90_TTC_HOURS,
  CAST(ROUND(AVG(IFF(is_open_asof=0, same_day_flag, NULL)), 2) AS NUMBER(38,2))      AS SAME_DAY_CLOSE_RATE,
  CAST(ROUND(AVG(emails_total), 2) AS NUMBER(38,2))                                   AS AVG_EMAILS_TOTAL,
  CAST(ROUND(COUNT_IF(CONTACT_REASON = 'Null') / NULLIF(COUNT(*), 0), 2)
       AS NUMBER(38,2))                                                               AS PCT_CONTACT_REASON_NULL
FROM enriched
GROUP BY CASE_ORIGIN
ORDER BY SHARE_OF_TOTAL DESC, OPEN_NOW_RATE DESC;

"""

df = client.query_to_df(query)
pd.set_option('display.max_rows', None)  
df
# Out:
#    CASE_ORIGIN TOTAL_CASES SHARE_OF_TOTAL  OPEN_NOW OPEN_NOW_RATE  \
# 0  Form_Mobile        2241           0.36      1030          0.46
# 1        Phone        1180           0.19       197          0.17
# 2        Email        1030           0.17       368          0.36
# 3     Form_Web         850           0.14       416          0.49
# 4     Outbound         418           0.07        74          0.18
# 5         Post         282           0.05        74          0.26
# 6   Backoffice         187           0.03       153          0.82
# 7  OSKAR Email           1           0.00         0          0.00
# 8  Order Email           3           0.00         0          0.00
#
#   OPEN_7D_RATE  CLOSED_CASES MEDIAN_TTC_HOURS P90_TTC_HOURS  \
# 0         0.40          1211            24.00         97.00
# 1         0.15           983             0.00         23.80
# 2         0.31           662            24.00         88.70
# 3         0.45           434            23.00         97.00
# 4         0.33           344             0.00         25.40
# 5         0.28           208            24.00        115.30
# 6         0.66            34            93.00        160.40
# 7         None             1            96.00         96.00
# 8         0.00             3            20.00         36.80
#
#   SAME_DAY_CLOSE_RATE AVG_EMAILS_TOTAL PCT_CONTACT_REASON_NULL
# 0                0.27             2.03                    0.51
# 1                0.87             0.90                    0.00
# 2                0.20             2.46                    0.31
# 3                0.21             1.98                    0.56
# 4                0.86             1.18                    0.54
# 5                0.15             2.34                    0.28
# 6                0.00             2.37                    0.01
# 7                0.00             2.00                    0.00
# 8                0.33             6.00                    0.00

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH base AS (
  SELECT
    EXTRACT(hour FROM CREATED_DATE) AS hour_of_day,
    CASE_ORIGIN
  FROM SCALABLECAPITAL.PUBLIC.CASES
  WHERE CREATED_DATE IS NOT NULL
),
per_hour AS (
  SELECT
    hour_of_day,
    COUNT(*) AS total_cases,
    SUM(IFF(CASE_ORIGIN = 'Form_Mobile', 1, 0)) AS c_form_mobile,
    SUM(IFF(CASE_ORIGIN = 'Form_Web',    1, 0)) AS c_form_web,
    SUM(IFF(CASE_ORIGIN = 'Phone',       1, 0)) AS c_phone,
    SUM(IFF(CASE_ORIGIN = 'Email',       1, 0)) AS c_email,
    SUM(IFF(CASE_ORIGIN = 'Outbound',    1, 0)) AS c_outbound,
    SUM(IFF(CASE_ORIGIN = 'Post',        1, 0)) AS c_post,
    SUM(IFF(CASE_ORIGIN = 'Backoffice',  1, 0)) AS c_backoffice,
    SUM(IFF(CASE_ORIGIN = 'OSKAR Email', 1, 0)) AS c_oskar_email,
    SUM(IFF(CASE_ORIGIN = 'Order Email', 1, 0)) AS c_order_email
  FROM base
  GROUP BY 1
)
SELECT
  hour_of_day,
  CAST(total_cases AS NUMBER(38)) AS total_cases,
  CAST(ROUND(c_form_mobile  / NULLIF(total_cases, 0), 2) AS NUMBER(38,2)) AS share_form_mobile,
  CAST(ROUND(c_form_web     / NULLIF(total_cases, 0), 2) AS NUMBER(38,2)) AS share_form_web,
  CAST(ROUND(c_phone        / NULLIF(total_cases, 0), 2) AS NUMBER(38,2)) AS share_phone,
  CAST(ROUND(c_email        / NULLIF(total_cases, 0), 2) AS NUMBER(38,2)) AS share_email,
  CAST(ROUND(c_outbound     / NULLIF(total_cases, 0), 2) AS NUMBER(38,2)) AS share_outbound,
  CAST(ROUND(c_post         / NULLIF(total_cases, 0), 2) AS NUMBER(38,2)) AS share_post,
  CAST(ROUND(c_backoffice   / NULLIF(total_cases, 0), 2) AS NUMBER(38,2)) AS share_backoffice,
  CAST(ROUND(c_oskar_email  / NULLIF(total_cases, 0), 2) AS NUMBER(38,2)) AS share_oskar_email,
  CAST(ROUND(c_order_email  / NULLIF(total_cases, 0), 2) AS NUMBER(38,2)) AS share_order_email
FROM per_hour
ORDER BY hour_of_day;
"""

df = client.query_to_df(query)
pd.set_option('display.max_rows', None)  
df
# Out:
#     HOUR_OF_DAY TOTAL_CASES SHARE_FORM_MOBILE SHARE_FORM_WEB SHARE_PHONE  \
# 0             0          49              0.57           0.12        0.00
# 1             1          24              0.83           0.04        0.00
# 2             2          12              0.58           0.17        0.00
# 3             3          16              0.50           0.06        0.00
# 4             4           8              0.75           0.00        0.00
# 5             5          17              0.82           0.00        0.00
# 6             6          56              0.80           0.04        0.00
# 7             7         138              0.73           0.09        0.00
# 8             8         311              0.50           0.13        0.18
# 9             9         482              0.38           0.11        0.26
# 10           10         500              0.34           0.17        0.25
# 11           11         487              0.36           0.16        0.25
# 12           12         508              0.34           0.14        0.27
# 13           13         493              0.30           0.16        0.22
# 14           14         446              0.24           0.14        0.21
# 15           15         432              0.28           0.16        0.21
# 16           16         656              0.21           0.09        0.16
# 17           17         394              0.24           0.12        0.23
# 18           18         286              0.35           0.18        0.23
# 19           19         263              0.40           0.16        0.22
# 20           20         203              0.53           0.16        0.02
# 21           21         177              0.55           0.18        0.00
# 22           22         159              0.60           0.11        0.00
# 23           23          75              0.53           0.13        0.00
#
#    SHARE_EMAIL SHARE_OUTBOUND SHARE_POST SHARE_BACKOFFICE SHARE_OSKAR_EMAIL  \
# 0         0.24           0.00       0.00             0.06              0.00
# 1         0.08           0.00       0.00             0.04              0.00
# 2         0.25           0.00       0.00             0.00              0.00
# 3         0.44           0.00       0.00             0.00              0.00
# 4         0.13           0.00       0.00             0.13              0.00
# 5         0.12           0.00       0.00             0.06              0.00
# 6         0.16           0.00       0.00             0.00              0.00
# 7         0.17           0.00       0.00             0.01              0.00
# 8         0.12           0.05       0.00             0.03              0.00
# 9         0.15           0.08       0.00             0.02              0.00
# 10        0.20           0.03       0.00             0.02              0.00
# 11        0.16           0.05       0.00             0.02              0.00
# 12        0.16           0.07       0.00             0.02              0.00
# 13        0.15           0.13       0.00             0.03              0.00
# 14        0.16           0.21       0.01             0.03              0.00
# 15        0.16           0.15       0.02             0.03              0.00
# 16        0.11           0.05       0.36             0.02              0.00
# 17        0.23           0.08       0.06             0.05              0.00
# 18        0.14           0.01       0.03             0.05              0.00
# 19        0.16           0.00       0.00             0.05              0.00
# 20        0.22           0.00       0.00             0.07              0.00
# 21        0.21           0.00       0.00             0.05              0.00
# 22        0.21           0.00       0.00             0.07              0.00
# 23        0.32           0.00       0.00             0.01              0.00
#
#    SHARE_ORDER_EMAIL
# 0               0.00
# 1               0.00
# 2               0.00
# 3               0.00
# 4               0.00
# 5               0.00
# 6               0.00
# 7               0.00
# 8               0.00
# 9               0.00
# 10              0.00
# 11              0.00
# 12              0.00
# 13              0.00
# 14              0.00
# 15              0.00
# 16              0.00
# 17              0.00
# 18              0.00
# 19              0.00
# 20              0.00
# 21              0.00
# 22              0.00
# 23              0.00

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH anchor AS (
  SELECT TO_TIMESTAMP_NTZ('2025-08-13 10:06:21') AS window_end
),
base AS (
  SELECT
    CASE_ID,
    CREATED_DATE,
    CLOSED_DATE,
    CONTACT_REASON,
    BUCKET,
    TOPIC
  FROM SCALABLECAPITAL.PUBLIC.CASES
  WHERE CONTACT_REASON = 'System Issue'
),
enriched AS (
  SELECT
    b.*,
    /* is it still open as of the snapshot window_end? */
    IFF(
      b.CLOSED_DATE IS NULL OR b.CLOSED_DATE > (SELECT window_end FROM anchor),
      1, 0
    ) AS is_open_asof,
    /* how long it's been alive as of close/snapshot */
    DATEDIFF(
      'hour',
      b.CREATED_DATE,
      LEAST(
        COALESCE(b.CLOSED_DATE, (SELECT window_end FROM anchor)),
        (SELECT window_end FROM anchor)
      )
    ) AS age_hours_asof,
    /* eligible for 7d aging bucket */
    IFF(
      DATEDIFF('hour', b.CREATED_DATE, (SELECT window_end FROM anchor)) >= 168,
      1, 0
    ) AS elig_7d
  FROM base b
)
SELECT
  BUCKET,
  TOPIC,
  /* total system issue cases in this bucket/topic */
  CAST(COUNT(*) AS NUMBER(38)) AS SYSTEM_ISSUE_CASES,

  /* how many are still open right now */
  CAST(COUNT_IF(is_open_asof = 1) AS NUMBER(38)) AS OPEN_NOW,

  /* how "stuck" they are overall */
  CAST(ROUND(COUNT_IF(is_open_asof = 1) / NULLIF(COUNT(*), 0), 2)
       AS NUMBER(38,2)) AS OPEN_NOW_RATE
FROM enriched
GROUP BY BUCKET, TOPIC
ORDER BY SYSTEM_ISSUE_CASES DESC, OPEN_NOW_RATE DESC;
"""

df = client.query_to_df(query)
pd.set_option('display.max_rows', None)  
df
# Out:
#                          BUCKET  \
# 0            Account Management
# 1                Broker Trading
# 2                Broker Trading
# 3            Account Management
# 4            Account Management
# 5            Account Management
# 6                      Payments
# 7                      Payments
# 8   Broker Portfolio Management
# 9   Broker Portfolio Management
# 10               Broker Trading
# 11            Corporate Actions
# 12                        Taxes
# 13               Broker Trading
# 14  Broker Portfolio Management
# 15               Broker Trading
# 16               Broker Trading
# 17  Broker Portfolio Management
#
#                                              TOPIC SYSTEM_ISSUE_CASES  \
# 0                   Account Management - IT Issues                 52
# 1                        Broker Trading - Downtime                 16
# 2                    Broker Trading - Trade Issues                 16
# 3                         Account Management - 2FA                 13
# 4            Account Management - Client Documents                 11
# 5                        Account Management - MISC                  8
# 6                       Payments - Account Balance                  8
# 7                              Payments - Deposits                  7
# 8        Broker Portfolio Management - Transfer IN                  3
# 9   Broker Portfolio Management - Broker Functions                  3
# 10                  Broker Trading - Savings Plans                  3
# 11                 Corporate Actions - Stock Split                  2
# 12                                    Taxes - MISC                  1
# 13                    Broker Trading - Derivatives                  1
# 14              Broker Portfolio Management - MISC                  1
# 15                           Broker Trading - MISC                  1
# 16             Broker Trading - Order Instructions                  1
# 17      Broker Portfolio Management - Transfer OUT                  1
#
#     OPEN_NOW OPEN_NOW_RATE
# 0          7          0.13
# 1          2          0.13
# 2          1          0.06
# 3          3          0.23
# 4          0          0.00
# 5          1          0.13
# 6          0          0.00
# 7          0          0.00
# 8          3          1.00
# 9          1          0.33
# 10         0          0.00
# 11         1          0.50
# 12         1          1.00
# 13         0          0.00
# 14         0          0.00
# 15         0          0.00
# 16         0          0.00
# 17         0          0.00

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH base AS (
  SELECT CASE_ORIGIN, BUCKET
  FROM SCALABLECAPITAL.PUBLIC.CASES
),
enriched AS (
  SELECT
    CASE_ORIGIN,
    BUCKET,
    IFF(BUCKET IS NULL OR TRIM(BUCKET) = '' OR UPPER(TRIM(BUCKET)) = 'NULL', 1, 0) AS is_bucket_nullish
  FROM base
)
SELECT
  CASE_ORIGIN,
  COUNT(*) AS total_cases,
  COUNT_IF(is_bucket_nullish = 1) AS null_buckets,
  CAST(ROUND(COUNT_IF(is_bucket_nullish = 1) / NULLIF(COUNT(*),0), 2) AS NUMBER(38,2)) AS null_bucket_rate
FROM enriched
GROUP BY CASE_ORIGIN
ORDER BY null_buckets DESC, null_bucket_rate DESC;
"""

df = client.query_to_df(query)
pd.set_option('display.max_rows', None)  
df
# Out:
#    CASE_ORIGIN  TOTAL_CASES  NULL_BUCKETS NULL_BUCKET_RATE
# 0        Email         1030           115             0.11
# 1  Form_Mobile         2241             1             0.00
# 2     Form_Web          850             0             0.00
# 3         Post          282             0             0.00
# 4     Outbound          418             0             0.00
# 5  OSKAR Email            1             0             0.00
# 6   Backoffice          187             0             0.00
# 7        Phone         1180             0             0.00
# 8  Order Email            3             0             0.00

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH base AS (
  SELECT BUCKET, CONTACT_REASON
  FROM SCALABLECAPITAL.PUBLIC.CASES
),
enriched AS (
  SELECT
    COALESCE(BUCKET, '(NULL)') AS bucket_group,
    IFF(CONTACT_REASON IS NULL OR TRIM(CONTACT_REASON) = '' OR UPPER(TRIM(CONTACT_REASON)) = 'NULL', 1, 0) AS is_cr_nullish
  FROM base
)
SELECT
  bucket_group AS bucket,
  COUNT(*) AS total_cases,
  COUNT_IF(is_cr_nullish = 1) AS null_contact_reasons,
  CAST(ROUND(COUNT_IF(is_cr_nullish = 1) / NULLIF(COUNT(*),0), 2) AS NUMBER(38,2)) AS null_contact_reason_rate
FROM enriched
GROUP BY bucket_group
ORDER BY null_contact_reason_rate DESC;
"""

df = client.query_to_df(query)
pd.set_option('display.max_rows', None)  
df
# Out:
#                         BUCKET  TOTAL_CASES  NULL_CONTACT_REASONS  \
# 0                         Null          116                   115
# 1                        Taxes          463                   332
# 2               Broker Trading          929                   443
# 3  Broker Portfolio Management          773                   315
# 4                     Goodwill          112                    35
# 5           Account Management         1759                   520
# 6              Account Opening          758                   187
# 7                     Payments          717                   175
# 8            Corporate Actions          545                   115
# 9                        Other           20                     2
#
#   NULL_CONTACT_REASON_RATE
# 0                     0.99
# 1                     0.72
# 2                     0.48
# 3                     0.41
# 4                     0.31
# 5                     0.30
# 6                     0.25
# 7                     0.24
# 8                     0.21
# 9                     0.10

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH base AS (
  SELECT BUCKET, TOPIC
  FROM SCALABLECAPITAL.PUBLIC.CASES
),
enriched AS (
  SELECT
    COALESCE(BUCKET, '(NULL)') AS bucket_group,
    IFF(TOPIC IS NULL OR TRIM(TOPIC) = '' OR UPPER(TRIM(TOPIC)) = 'NULL', 1, 0) AS is_topic_nullish
  FROM base
)
SELECT
  bucket_group AS bucket,
  COUNT(*) AS total_cases,
  COUNT_IF(is_topic_nullish = 1) AS null_topics,
  CAST(ROUND(COUNT_IF(is_topic_nullish = 1) / NULLIF(COUNT(*),0), 2) AS NUMBER(38,2)) AS null_topic_rate
FROM enriched
GROUP BY bucket_group
ORDER BY null_topics DESC, null_topic_rate DESC;
"""

df = client.query_to_df(query)
pd.set_option('display.max_rows', None)  
df
# Out:
#                         BUCKET  TOTAL_CASES  NULL_TOPICS NULL_TOPIC_RATE
# 0                         Null          116          116            1.00
# 1  Broker Portfolio Management          773            0            0.00
# 2               Broker Trading          929            0            0.00
# 3                        Taxes          463            0            0.00
# 4              Account Opening          758            0            0.00
# 5           Account Management         1759            0            0.00
# 6                     Payments          717            0            0.00
# 7                     Goodwill          112            0            0.00
# 8            Corporate Actions          545            0            0.00
# 9                        Other           20            0            0.00

# %%
# Sample: select from calls with triple-quoted SQL
query = """
WITH base AS (
  SELECT TOPIC, SUB_TOPIC
  FROM SCALABLECAPITAL.PUBLIC.CASES
),
enriched AS (
  SELECT
    COALESCE(TOPIC, '(NULL)') AS topic_group,
    IFF(SUB_TOPIC IS NULL OR TRIM(SUB_TOPIC) = '' OR UPPER(TRIM(SUB_TOPIC)) = 'NULL', 1, 0) AS is_sub_topic_nullish
  FROM base
)
SELECT
  topic_group AS topic,
  COUNT(*) AS total_cases,
  COUNT_IF(is_sub_topic_nullish = 1) AS null_sub_topics,
  CAST(ROUND(COUNT_IF(is_sub_topic_nullish = 1) / NULLIF(COUNT(*),0), 2) AS NUMBER(38,2)) AS null_sub_topic_rate
FROM enriched
GROUP BY topic_group
ORDER BY null_sub_topic_rate DESC, total_cases DESC;
"""

df = client.query_to_df(query)
pd.set_option('display.max_rows', None)  
df
# Out:
#                                              TOPIC  TOTAL_CASES  \
# 0                        Account Management - MISC          498
# 1                  Corporate Actions - Stock Split          350
# 2                   Broker Trading - Savings Plans          346
# 3       Broker Portfolio Management - Transfer OUT          318
# 4                            Broker Trading - MISC          298
# 5        Broker Portfolio Management - Transfer IN          291
# 6                              Payments - Deposits          249
# 7                Account Management - Cancellation          218
# 8                           Payments - Withdrawals          199
# 9                           Account Opening - MISC          196
# 10                        Account Management - 2FA          182
# 11                                    Taxes - MISC          174
# 12                   Broker Trading - Trade Issues          174
# 13              Broker Portfolio Management - MISC          135
# 14                      Payments - Account Balance          116
# 15                                            Null          116
# 16                 Taxes - Tax Calculation Details           84
# 17                        Corporate Actions - MISC           81
# 18                           Taxes - Tax Allowance           79
# 19                                 Payments - MISC           75
# 20                  Taxes - Yearly Tax Certificate           69
# 21           Corporate Actions - Dividend Payments           64
# 22                             Goodwill - Referral           52
# 23                Corporate Actions - Instructions           45
# 24                             Payments - Interest           40
# 25                               Payments - Credit           38
# 26                                 Goodwill - Fees           34
# 27                       Broker Trading - Downtime           29
# 28  Broker Portfolio Management - Broker Functions           29
# 29                               Other - Marketing           20
# 30                    Broker Trading - Derivatives           19
# 31          Taxes - German Tax ID and Church Taxes           19
# 32             Broker Trading - Order Instructions           17
# 33                                  Taxes - W8-Ben           15
# 34            Taxes - Loss Pot Certificate Request           13
# 35                              Goodwill - Refunds           13
# 36              Account Management - Data Deletion           13
# 37                              Goodwill - Rewards           11
# 38                          Taxes - Non Assessment           10
# 39           Account Management - Non-EU Residents            9
# 40            Corporate Actions - Capital Increase            3
# 41                    Broker Trading - EIX Support            3
# 42                                 Goodwill - MISC            2
# 43                    Corporate Actions - Spin-off            2
# 44               Account Opening - Opening Process          220
# 45                         Broker Trading - Crypto           19
# 46                  Account Management - IT Issues          167
# 47                Account Management - Data Change          332
# 48                           Account Opening - KYC          166
# 49           Account Management - Client Documents          340
# 50          Account Opening - Account Reactivation          176
# 51              Broker Trading - Scalable Products           24
#
#     NULL_SUB_TOPICS NULL_SUB_TOPIC_RATE
# 0               498                1.00
# 1               349                1.00
# 2               346                1.00
# 3               318                1.00
# 4               298                1.00
# 5               291                1.00
# 6               249                1.00
# 7               218                1.00
# 8               199                1.00
# 9               196                1.00
# 10              182                1.00
# 11              174                1.00
# 12              174                1.00
# 13              135                1.00
# 14              116                1.00
# 15              116                1.00
# 16               84                1.00
# 17               81                1.00
# 18               79                1.00
# 19               75                1.00
# 20               69                1.00
# 21               64                1.00
# 22               52                1.00
# 23               45                1.00
# 24               40                1.00
# 25               38                1.00
# 26               34                1.00
# 27               29                1.00
# 28               29                1.00
# 29               20                1.00
# 30               19                1.00
# 31               19                1.00
# 32               17                1.00
# 33               15                1.00
# 34               13                1.00
# 35               13                1.00
# 36               13                1.00
# 37               11                1.00
# 38               10                1.00
# 39                9                1.00
# 40                3                1.00
# 41                3                1.00
# 42                2                1.00
# 43                2                1.00
# 44              212                0.96
# 45               18                0.95
# 46              100                0.60
# 47              181                0.55
# 48               92                0.55
# 49              128                0.38
# 50               35                0.20
# 51                2                0.08
